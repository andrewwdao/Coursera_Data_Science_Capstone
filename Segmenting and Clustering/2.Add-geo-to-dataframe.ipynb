# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto
#
# Peer-graded Assignment on Week3 of the Applied Data Science Capstone
#
# ## Add Long and Lat to Dataframe using Geocoder

# %% [markdown]
# ### Prepare the environment

# %%
# Install the needed libraries
# urllib is a standard library
! pip install beautifulsoup4 # install beautifulsoup4
! pip install geocoder # install geocoder
# Out:
# ...
#      |████████████████████████████████| 102kB 16.5MB/s ta 0:00:01
# ...
#      |████████████████████████████████| 829kB 28.8MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 81kB 15.5MB/s eta 0:00:01
# ...
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# ...

# %%
# --------- Import libraries --------------
import geocoder # import geocoder
import pandas as pd

# %% [markdown]
# ### Get the geocoder package

# %%
# ---------- Former way - Get it directly from google ---------
# # initialize your variable to None
# lat_lng_coords = None

# # loop until you get the coordinates
# while(lat_lng_coords is None):
#   g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#   lat_lng_coords = g.latlng

# latitude = lat_lng_coords[0]
# longitude = lat_lng_coords[1]

# ----------- Get it from a pre-processed csv file ------------
geo_df = pd.read_csv('http://cocl.us/Geospatial_data')
geo_df.rename(columns = {'Postal Code':'PostalCode'}, inplace = True)
geo_df
# Out:
#     PostalCode   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# ..         ...        ...        ...
# 98         M9N  43.706876 -79.518188
# 99         M9P  43.696319 -79.532242
# 100        M9R  43.688905 -79.554724
# 101        M9V  43.739416 -79.588437
# 102        M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# ### Get the processed dataframe from previous assignment

# %%
# ----------- Get the processed dataframe from previous assignment ------------
df = pd.read_csv('Canada_neighborhood.csv')
df
# Out:
#     PostalCode      Borough                                       Neighborhood
# 0          M1B  Scarborough                                     Rouge, Malvern
# 1          M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2          M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3          M1G  Scarborough                                             Woburn
# 4          M1H  Scarborough                                          Cedarbrae
# ..         ...          ...                                                ...
# 98         M9N         York                                             Weston
# 99         M9P    Etobicoke                                          Westmount
# 100        M9R    Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 101        M9V    Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102        M9W    Etobicoke                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# ### Merge 2 dataframe into 1 - Done

# %%
result = pd.merge(df, geo_df, on='PostalCode')
result[result['Borough']=='East Toronto']
# Out:
#    PostalCode       Borough  \
# 37        M4E  East Toronto
# 41        M4K  East Toronto
# 42        M4L  East Toronto
# 43        M4M  East Toronto
# 87        M7Y  East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 37                                        The Beaches  43.676357 -79.293031
# 41                       The Danforth West, Riverdale  43.679557 -79.352188
# 42                     The Beaches West, India Bazaar  43.668999 -79.315572
# 43                                    Studio District  43.659526 -79.340923
# 87  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558

# %%
# save it to another csv file
result.to_csv('Canada_neighborhood_geo.csv',index=False)
print('Dataframe saved!')
# Out:
# Dataframe saved!
